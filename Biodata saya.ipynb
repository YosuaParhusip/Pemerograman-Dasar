# %% [markdown]
# <a href="https://colab.research.google.com/github/YosuaParhusip/Pemerograman-Dasar/blob/main/Biodata%20saya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata Satya

Nama = "Yosua"
Nim = "4232501020"
Umur = 20
Jurusan = "Elektro"
Semester = 3
Asalsekolah = "Sman 5 Batam"
Matakuliah = 'Pemerograman Dasar'
Email = "jooprp.6@gmail.com"
Kewarganegaraan = "Indonesia"
Status_lulus = False

print (Nama)
print (Nim)
print (Umur)
print (Jurusan)
print (Semester)
print (Asalsekolah)
print (Matakuliah)
print (Email)
print (Kewarganegaraan)
print (Status_lulus)
# Out:
# Yosua
# 4232501020
# 20
# Elektro
# 3
# Sman 5 Batam
# Pemerograman Dasar
# jooprp.6@gmail.com
# Indonesia
# False
